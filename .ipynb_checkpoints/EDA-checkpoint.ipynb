# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(color_codes=True)

import matplotlib.dates as mdates

# %%
# Lade CSV aus Ordner -> komplette Dashboard Datei
df = pd.read_csv('dashboard_time_series_complete.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158424 entries, 0 to 158423
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           158424 non-null  int64
#  1   Date                 158424 non-null  object
#  2   Country              158424 non-null  object
#  3   Confirmed_Cases      158424 non-null  int64
#  4   Deaths               158424 non-null  int64
#  5   New_Cases            158424 non-null  int64
#  6   New_Deaths           158424 non-null  int64
#  7   Doses_admin          158424 non-null  float64
#  8   GDP                  158424 non-null  float64
#  9   Population           158424 non-null  int64
#  10  Confirmed_Cases_rel  158424 non-null  float64
#  11  Deaths_rel           158424 non-null  float64
#  12  Doses_admin_per_100  158424 non-null  float64
#  13  GDP_pro_Kopf         158424 non-null  float64
#  14  GNI_2019             158424 non-null  float64
#  15  Income group         158424 non-null  object
#  16  _merge               158424 non-null  object
#  17  total_tests          158424 non-null  float64
#  18  new_tests            158424 non-null  float64
#  19  total_tests_rel      158424 non-null  float64
# dtypes: float64(10), int64(6), object(4)
# memory usage: 24.2+ MB

# %%
# Number of countries
df['Country'].nunique()
# Out:
# 184

# %%
df[{'new_tests', 'total_tests', 'total_tests_rel'}].describe()
# Out:
#         total_tests  total_tests_rel     new_tests
# count  1.584240e+05    158424.000000  1.584240e+05
# mean   7.811539e+06        39.896680  2.520361e+04
# std    4.683051e+07       140.044065  1.493215e+05
# min    0.000000e+00         0.000000  0.000000e+00
# 25%    0.000000e+00         0.000000  0.000000e+00
# 50%    0.000000e+00         0.000000  0.000000e+00
# 75%    1.584701e+06        16.055661  6.015000e+03
# max    9.214000e+09      2411.483120  3.585563e+07

# %%
# Line Plot -> doses admin / date
country_list = ['Germany', 'Angola', 'US', 'Belarus', 'India']
filtered_df = df[df['Country'].isin(country_list)]

x_date = filtered_df['Date']
y_dosis = filtered_df['Doses_admin_per_100']


years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y-%m') #This is a format

fig, axes = plt.subplots(figsize=(20,10))

sns.lineplot(x=x_date, y=y_dosis,hue=filtered_df['Country'], marker = 'o')

axes.xaxis.set_major_locator(months)
#axes.xaxis.set_major_formatter(years_fmt)
#axes.xaxis.set_minor_locator(months)

plt.xticks(rotation = 'vertical')
plt.title('Zeitlicher Verlauf der verabreichten Impfdosen ab 22.Januar 2020', fontdict={'fontsize':30})
plt.show()

# %% [markdown]
# ### Thesen Scatterplot (mit Todesfälle)
# #### - Länder mit hohem GDP_pro_Kopf haben mehr Impfdosen verabreicht
# #### - es gibt auch viele Länder mit geringem GDP_pro_Kopf, die viele Impfdosen verabreichen konnten
# #### - viele Todesfälle ehr in reichen Ländern -> Werden die Toten in armen Ländern nicht identifiziert??

# %% [markdown]
# ### Thesen Scatterplot (mit Corona-Fällen)
# #### - reiche Länder haben mehr Fälle (weil mehr Testungen?? -> keine weltweiten Daten zu Testungen)
# #### - arme Länder haben ehr weniger Impfdosen verimpft

# %%
fig = plt.gcf()

# aktuellstes Datum bekommen
date_max = df['Date'].max()

# Change seaborn plot size
fig.set_size_inches(15, 10)

# Filter -> zeige nur alle Daten vom letzten Datum
data_scatter = df[df['Date'] == date_max]

# Filter -> alle Werte "Doses_admin_per_100" größer als 0
data_scatter = data_scatter[data_scatter['Doses_admin_per_100'] > 0]

splot = sns.regplot(x=data_scatter["GNI_2019"], y=data_scatter["Doses_admin_per_100"], 
                    fit_reg=True, marker='o', scatter_kws={'s':data_scatter["Deaths_rel"]*1500},
                   line_kws={"color":"r","alpha":0.7,"lw":3})
splot.set(xscale="log")
splot.set_title('Anzahl Impfdosen / BNE pro Kopf / rel. Anzahl Tote',fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Anzahl Impfdosen / BNE pro Kopf / rel. Anzahl Tote')

# %%
fig = plt.gcf()

# Change seaborn plot size
fig.set_size_inches(15, 10)

# Filter -> zeige nur alle Daten vom letzten Datum
data_scatter = df[df['Date'] == date_max]

# Filter -> alle Werte "Doses_admin_per_100" größer als 0
data_scatter = data_scatter[data_scatter['Doses_admin_per_100'] > 0]

splot = sns.regplot(x=data_scatter["GNI_2019"], y=data_scatter["Doses_admin_per_100"], 
                    fit_reg=True, scatter_kws={'s':data_scatter["Confirmed_Cases_rel"]*15},
                   line_kws={"color":"r","alpha":0.7,"lw":3})
splot.set(xscale="log")
splot.set_title('Anzahl Impfdosen / BNE pro Kopf / rel. Anzahl Covid-Fälle',fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Anzahl Impfdosen / BNE pro Kopf / rel. Anzahl Covid-Fälle')

# %%
fig = plt.gcf()

# Change seaborn plot size
fig.set_size_inches(15, 10)

# Filter -> zeige nur alle Daten vom 01.05.2022
data_scatter = df[df['Date'] == "2022-05-01"]

# Filter -> alle Werte "total_tests" größer als 0
data_scatter = data_scatter[data_scatter['total_tests'] > 0]

splot = sns.regplot(x=data_scatter["GNI_2019"], y=data_scatter["Confirmed_Cases_rel"], 
                    fit_reg=True, scatter_kws={'s':(data_scatter["total_tests_rel"])},
                   line_kws={"color":"r","alpha":0.7,"lw":3})
splot.set(xscale="log")
splot.set_title('Anzahl Impfdosen / BNE pro Kopf / rel. Anzahl Tests',fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Anzahl Impfdosen / BNE pro Kopf / rel. Anzahl Tests')

# %%
#Korrelationsmatrix nach Spearman -> da nicht linearer Zusammenhang
df_corr = df[df['Date'] == "2022-05-01"]
df_corr = df_corr[{"GNI_2019", 'Doses_admin_per_100', 'Deaths_rel', "Confirmed_Cases_rel", "total_tests_rel", "GDP_pro_Kopf"}]

df_corr.corr(method="spearman").round(3).style.background_gradient(cmap='YlOrRd', high=0.5)
# Out:
# <style type="text/css">
# #T_f0577_row0_col0, #T_f0577_row1_col1, #T_f0577_row2_col2, #T_f0577_row3_col3, #T_f0577_row4_col4, #T_f0577_row5_col5 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_f0577_row0_col1 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_f0577_row0_col2 {
#   background-color: #fff3ae;
#   color: #000000;
# }
# #T_f0577_row0_col3 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_f0577_row0_col4 {
#   background-color: #febe59;
#   color: #000000;
# }
# #T_f0577_row0_col5 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_f0577_row1_col0 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_f0577_row1_col2 {
#   background-color: #ffea9b;
#   color: #000000;
# }
# #T_f0577_row1_col3 {
#   background-color: #ffe794;
#   color: #000000;
# }
# #T_f0577_row1_col4 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_f0577_row1_col5 {
#   background-color: #feab49;
#   color: #000000;
# }
# #T_f0577_row2_col0, #T_f0577_row2_col1, #T_f0577_row2_col3, #T_f0577_row2_col4, #T_f0577_row2_col5, #T_f0577_row3_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_f0577_row3_col0 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_f0577_row3_col1 {
#   background-color: #fffcc4;
#   color: #000000;
# }
# #T_f0577_row3_col4 {
#   background-color: #fd9941;
#   color: #000000;
# }
# #T_f0577_row3_col5 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_f0577_row4_col0 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_f0577_row4_col1 {
#   background-color: #fee085;
#   color: #000000;
# }
# #T_f0577_row4_col2 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_f0577_row4_col3 {
#   background-color: #fd923e;
#   color: #000000;
# }
# #T_f0577_row4_col5 {
#   background-color: #fea747;
#   color: #000000;
# }
# #T_f0577_row5_col0 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_f0577_row5_col1 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_f0577_row5_col2 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_f0577_row5_col3 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_f0577_row5_col4 {
#   background-color: #fea044;
#   color: #000000;
# }
# </style>
# <table id="T_f0577_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Doses_admin_per_100</th>
#       <th class="col_heading level0 col1" >GNI_2019</th>
#       <th class="col_heading level0 col2" >total_tests_rel</th>
#       <th class="col_heading level0 col3" >Deaths_rel</th>
#       <th class="col_heading level0 col4" >Confirmed_Cases_rel</th>
#       <th class="col_heading level0 col5" >GDP_pro_Kopf</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0577_level0_row0" class="row_heading level0 row0" >Doses_admin_per_100</th>
#       <td id="T_f0577_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f0577_row0_col1" class="data row0 col1" >0.560000</td>
#       <td id="T_f0577_row0_col2" class="data row0 col2" >0.350000</td>
#       <td id="T_f0577_row0_col3" class="data row0 col3" >0.426000</td>
#       <td id="T_f0577_row0_col4" class="data row0 col4" >0.676000</td>
#       <td id="T_f0577_row0_col5" class="data row0 col5" >0.683000</td>
#     </tr>
#     <tr>
#       <th id="T_f0577_level0_row1" class="row_heading level0 row1" >GNI_2019</th>
#       <td id="T_f0577_row1_col0" class="data row1 col0" >0.560000</td>
#       <td id="T_f0577_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f0577_row1_col2" class="data row1 col2" >0.412000</td>
#       <td id="T_f0577_row1_col3" class="data row1 col3" >0.435000</td>
#       <td id="T_f0577_row1_col4" class="data row1 col4" >0.592000</td>
#       <td id="T_f0577_row1_col5" class="data row1 col5" >0.763000</td>
#     </tr>
#     <tr>
#       <th id="T_f0577_level0_row2" class="row_heading level0 row2" >total_tests_rel</th>
#       <td id="T_f0577_row2_col0" class="data row2 col0" >0.350000</td>
#       <td id="T_f0577_row2_col1" class="data row2 col1" >0.412000</td>
#       <td id="T_f0577_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f0577_row2_col3" class="data row2 col3" >0.252000</td>
#       <td id="T_f0577_row2_col4" class="data row2 col4" >0.340000</td>
#       <td id="T_f0577_row2_col5" class="data row2 col5" >0.406000</td>
#     </tr>
#     <tr>
#       <th id="T_f0577_level0_row3" class="row_heading level0 row3" >Deaths_rel</th>
#       <td id="T_f0577_row3_col0" class="data row3 col0" >0.426000</td>
#       <td id="T_f0577_row3_col1" class="data row3 col1" >0.435000</td>
#       <td id="T_f0577_row3_col2" class="data row3 col2" >0.252000</td>
#       <td id="T_f0577_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f0577_row3_col4" class="data row3 col4" >0.794000</td>
#       <td id="T_f0577_row3_col5" class="data row3 col5" >0.595000</td>
#     </tr>
#     <tr>
#       <th id="T_f0577_level0_row4" class="row_heading level0 row4" >Confirmed_Cases_rel</th>
#       <td id="T_f0577_row4_col0" class="data row4 col0" >0.676000</td>
#       <td id="T_f0577_row4_col1" class="data row4 col1" >0.592000</td>
#       <td id="T_f0577_row4_col2" class="data row4 col2" >0.340000</td>
#       <td id="T_f0577_row4_col3" class="data row4 col3" >0.794000</td>
#       <td id="T_f0577_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f0577_row4_col5" class="data row4 col5" >0.772000</td>
#     </tr>
#     <tr>
#       <th id="T_f0577_level0_row5" class="row_heading level0 row5" >GDP_pro_Kopf</th>
#       <td id="T_f0577_row5_col0" class="data row5 col0" >0.683000</td>
#       <td id="T_f0577_row5_col1" class="data row5 col1" >0.763000</td>
#       <td id="T_f0577_row5_col2" class="data row5 col2" >0.406000</td>
#       <td id="T_f0577_row5_col3" class="data row5 col3" >0.595000</td>
#       <td id="T_f0577_row5_col4" class="data row5 col4" >0.772000</td>
#       <td id="T_f0577_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
